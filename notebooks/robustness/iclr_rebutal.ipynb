# %%
# Reload modules automatically
# https://ipython.readthedocs.io/en/stable/config/extensions/autoreload.html
# %load_ext autoreload
# %autoreload 2
# %matplotlib widget

from utils import ExperimentManager

import matplotlib.pyplot as plt
import numpy as np

gcn_exp = dict(
    label = "GCN",
    collection = "rob_csbm_gcn",
    start_id = 1,
    end_id = 400,
    n_seeds = 10,
)
appnp_exp = dict(
    label = "APPNP",
    collection = "rob_csbm_appnp",
    start_id = 1,
    end_id = 320,
    n_seeds = 10,
)
gat_exp = dict(
    label = "GAT",
    collection = "rob_csbm_gat",
    start_id = [1, 301],
    end_id = [180, 440],
    n_seeds = 10,
)
gatv2_exp = dict(
    label = "GATv2",
    collection = "rob_csbm_gatv2",
    start_id = [1, 241],
    end_id = [180, 380],
    n_seeds = 10,
)
graphsage_exp = dict(
    label = "GraphSAGE",
    collection = "rob_csbm_graphsage",
    start_id = 1,
    end_id = 320,
    n_seeds = 10,
)
sgc_exp = dict(
    label="SGC",
    collection="rob_csbm_sgc",
    start_id = 1,
    end_id = 320,
    n_seeds = 10,
)
lp_exp = dict(
    label = "LP",
    collection = "rob_csbm_lp",
    start_id = 1,
    end_id = 320,
    n_seeds = 10,
)
mlp_exp = dict(
    label = "MLP",
    collection = "rob_csbm_mlp",
    start_id = [1, 251],
    end_id = [240, 330],
    n_seeds = 10,
)
gcn_lp_exp = dict(
    label = "GCN+LP",
    collection = "rob_csbm_gcn_lp",
    start_id = 1,
    end_id = 320,
    n_seeds = 10,
)
lineargcn_lp_exp = dict(
    label="LinearGCN",
    collection="rob_csbm_lineargcn",
    start_id = 1,
    end_id = 300,
    n_seeds = 10,
)
sgc_lp_exp = dict(
    label="SGC+LP",
    collection="rob_csbm_sgc_lp",
    start_id = 1,
    end_id = 320,
    n_seeds = 10,
)
appnp_lp_exp = dict(
    label = "APPNP+LP",
    collection = "rob_csbm_appnp_lp",
    start_id = 1,
    end_id = 320,
    n_seeds = 10,
)
gat_lp_exp = dict(
    label = "GAT+LP",
    collection = "rob_csbm_gat_lp",
    start_id = 1,
    end_id = 320,
    n_seeds = 10,
)
gatv2_lp_exp = dict(
    label = "GATv2+LP",
    collection = "rob_csbm_gatv2_lp",
    start_id = 1,
    end_id =  320,
    n_seeds = 10,
)
graphsage_lp_exp = dict(
    label = "GraphSAGE+LP",
    collection = "rob_csbm_graphsage_lp",
    start_id = 1,
    end_id = 320,
    n_seeds = 10,
)
mlp_lp_exp = dict(
    label = "MLP+LP",
    collection = "rob_csbm_mlp_lp",
    start_id = 1,
    end_id = 320,
    n_seeds = 10,
)

# %%
#This notebook is used to analyse the over- and under-robustness of models. 
Ks = [0.1, 0.5, 1.0, 1.5, 2.0, 3.0, 4.0, 5.0]

experiments = [mlp_exp,
               gcn_exp,
               #lineargcn_exp,
               sgc_exp,
               appnp_exp,
               gat_exp, 
               gatv2_exp, 
               graphsage_exp,
               lp_exp, 
               mlp_lp_exp,
               gcn_lp_exp,
               appnp_lp_exp, 
               #lineargcn_lp_exp,
               sgc_lp_exp,
               gatv2_lp_exp,
               gat_lp_exp,
               graphsage_lp_exp,
               ]
experiment_manager = ExperimentManager(experiments)

# %%
plt.close("all")
models = ["GCN", "GAT", "GATv2", "SGC", "MLP", "GraphSAGE", "APPNP", "LP", "APPNP+LP","GCN+LP", "GAT+LP", "GATv2+LP","MLP+LP", "GraphSAGE+LP", "SGC+LP"]
#models = ["GCN", "GCN+LP", "APPNP", "APPNP+LP", "GAT", "GAT+LP", "GATv2", "GATv2+LP"]
ylabel = r"$\mathbf{F_1^{rob}}$"
title = r"\textbf{Harmonic Mean of } $\mathbf{1-R^{over}}$ \textbf{and} $\mathbf{R^{adv}}$" #$\mathbf{R^{over}}$ 
experiment_manager.plot_f1(name="f1-robustness-v2", attack_overrobustness="l2-weak", 
                        attack_advrobustness="DICE", models=models, 
                        errorbars=True, title=title, spacing="even", ylabel=ylabel,
                        legend_loc="upper left", width = 0.8,
                        budget="deg+0", titlefont=15, tickfont=12, legendfont=13, 
                        xylabelfont=14, handlelength=1.5, labelspacing = 0.3, 
                        K_l=[0.1, 0.5, 1.0, 1.5, 2.0, 3.0, 4.0, 5.0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_138347/2663204781.py in <module>
#       4 ylabel = r"$\mathbf{F_1^{rob}}$"
#       5 title = r"\textbf{Harmonic Mean of } $\mathbf{1-R^{over}}$ \textbf{and} $\mathbf{R^{adv}}$" #$\mathbf{R^{over}}$
# ----> 6 experiment_manager.plot_f1(name="f1-robustness-v2", attack_overrobustness="l2-weak",
#       7                         attack_advrobustness="DICE", models=models,
#       8                         errorbars=True, title=title, spacing="even", ylabel=ylabel,
#
# ~/src/csbm/notebooks/robustness/utils.py in plot_f1(self, name, attack_overrobustness, attack_advrobustness, models, errorbars, spacing, label, title, ylabel, budget, legend_loc, titlefont, tickfont, xylabelfont, legendfont, outside_legend, width, handlelength, labelspacing, borderpad, tickfontweight, K_l)
#    1447             yerr = []
#    1448             for K in K_l:
# -> 1449                 f1_score = 2 * Rover_dict[label][K] * Radv_dict[label][K] / (Rover_dict[label][K] + Radv_dict[label][K])
#    1450                 y.append(np.mean(f1_score))
#    1451                 yerr.append(scipy.stats.sem(f1_score))
#
# KeyError: 'MLP'
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# camera ready
plt.close("all")
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "Time New Roman"
})
models = ["GCN", "GAT", "GATv2", "SGC", "MLP", "GraphSAGE", "APPNP", "LP", "APPNP+LP","GCN+LP", "GAT+LP", "GATv2+LP","MLP+LP", "GraphSAGE+LP", "SGC+LP"]
#models = ["MLP", "GCN", "APPNP", "SGC", "GAT", "GATv2", "GraphSAGE", "LP"]
#models = ["GCN"]
ylabel = r"$\mathbf{R^{over}}$"
title = r"" 
experiment_manager.plot_workshop(name="over-robustness-v2", attack="l2-weak", models=models, 
                        errorbars=True, title=title, spacing="even", ylabel=ylabel,
                        legend_loc="upper left", legend_cols=1, width = 0.8,
                        budget="deg+2", titlefont=23, tickfont=15, legendfont=13, 
                        xylabelfont=20, linewidth=3, markersize=10,
                        outside_legend=True, ylim=None, fontweight="bold",
                        tight_layout=True, handlelength=1.0,
                        K_l=[0.1, 0.5, 1.0, 1.5, 2.0, 3.0, 4.0, 5.0])
# Out:
# /nfs/homedirs/gosl/src/csbm/notebooks/robustness/utils.py:952: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([f"\\textbf{{{round(i, 2):.2f}}}" for i in ax.get_yticks()], fontsize=tickfont)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Main Document

# %%
# camera ready
plt.close("all")
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "Time New Roman"
})
models = ["GCN", "GAT", "GATv2", "SGC", "MLP", "GraphSAGE", "APPNP", "LP", "APPNP+LP","GCN+LP", "GAT+LP", "GATv2+LP","MLP+LP", "GraphSAGE+LP", "SGC+LP"]
#models = ["MLP", "GCN", "APPNP", "SGC", "GAT", "GATv2", "GraphSAGE", "LP"]
#models = ["GCN"]
ylabel = r""
title = r"" 
experiment_manager.plot_workshop(name="over-robustness-v2", attack="l2-weak", models=models, 
                        errorbars=True, title=title, spacing="even", ylabel=ylabel,
                        legend_loc="upper left", legend_cols=1, width = 0.8,
                        #budget="deg+0", 
                        titlefont=23, tickfont=15, legendfont=13, 
                        xylabelfont=20, linewidth=3, markersize=10,
                        outside_legend=True, ylim=None, fontweight="bold",
                        tight_layout=True, handlelength=1.5, labelspacing = 0.3, 
                        K_l=[0.1, 0.5, 1.0, 1.5, 2.0, 3.0, 4.0, 5.0])
# Out:
# /nfs/homedirs/gosl/src/csbm/notebooks/robustness/utils.py:960: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([f"\\textbf{{{round(i, 2):.1f}}}" for i in ax.get_yticks()], fontsize=tickfont)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Additional Attacks

# %%
# Reload modules automatically
# https://ipython.readthedocs.io/en/stable/config/extensions/autoreload.html
# %load_ext autoreload
# %autoreload 2
# %matplotlib widget

from utils import ExperimentManager

import matplotlib.pyplot as plt
import numpy as np

gcn_exp = dict(
    label = "GCN",
    collection = "rob_csbm_gcn",
    start_id = 1,
    end_id = 480,
    n_seeds = 10,
)
appnp_exp = dict(
    label = "APPNP",
    collection = "rob_csbm_appnp",
    start_id = 1,
    end_id = 480,
    n_seeds = 10,
)
gat_exp = dict(
    label = "GAT",
    collection = "rob_csbm_gat",
    start_id = [1, 301, 521],
    end_id = [180, 440, 680],
    n_seeds = 10,
)
gatv2_exp = dict(
    label = "GATv2",
    collection = "rob_csbm_gatv2",
    start_id = [1, 241, 461],
    end_id = [180, 380, 620],
    n_seeds = 10,
)
graphsage_exp = dict(
    label = "GraphSAGE",
    collection = "rob_csbm_graphsage",
    start_id = 1,
    end_id = 400,
    n_seeds = 10,
)
sgc_exp = dict(
    label="SGC",
    collection="rob_csbm_sgc",
    start_id = 1,
    end_id = 400,
    n_seeds = 10,
)
lp_exp = dict(
    label = "LP",
    collection = "rob_csbm_lp",
    start_id = 1,
    end_id = 400,
    n_seeds = 10,
)
mlp_exp = dict(
    label = "MLP",
    collection = "rob_csbm_mlp",
    start_id = [1, 251],
    end_id = [240, 410],
    n_seeds = 10,
)
gcn_lp_exp = dict(
    label = "GCN+LP",
    collection = "rob_csbm_gcn_lp",
    start_id = 1,
    end_id = 480,
    n_seeds = 10,
)
lineargcn_lp_exp = dict(
    label="LinearGCN",
    collection="rob_csbm_lineargcn",
    start_id = 1,
    end_id = 300,
    n_seeds = 10,
)
sgc_lp_exp = dict(
    label="SGC+LP",
    collection="rob_csbm_sgc_lp",
    start_id = 1,
    end_id = 400,
    n_seeds = 10,
)
appnp_lp_exp = dict(
    label = "APPNP+LP",
    collection = "rob_csbm_appnp_lp",
    start_id = 1,
    end_id = 480,
    n_seeds = 10,
)
gat_lp_exp = dict(
    label = "GAT+LP",
    collection = "rob_csbm_gat_lp",
    start_id = 1,
    end_id = 480,
    n_seeds = 10,
)
gatv2_lp_exp = dict(
    label = "GATv2+LP",
    collection = "rob_csbm_gatv2_lp",
    start_id = [1, 401],
    end_id =  [320,560],
    n_seeds = 10,
)
graphsage_lp_exp = dict(
    label = "GraphSAGE+LP",
    collection = "rob_csbm_graphsage_lp",
    start_id = 1,
    end_id = 400,
    n_seeds = 10,
)
mlp_lp_exp = dict(
    label = "MLP+LP",
    collection = "rob_csbm_mlp_lp",
    start_id = 1,
    end_id = 400,
    n_seeds = 10,
)

# %%
#This notebook is used to analyse the over- and under-robustness of models. 
Ks = [0.1, 0.5, 1.0, 1.5, 2.0, 3.0, 4.0, 5.0]

experiments = [mlp_exp,
               gcn_exp,
               #lineargcn_exp,
               sgc_exp,
               appnp_exp,
               gat_exp, 
               gatv2_exp, 
               graphsage_exp,
               lp_exp, 
               mlp_lp_exp,
               gcn_lp_exp,
               appnp_lp_exp, 
               #lineargcn_lp_exp,
               sgc_lp_exp,
               gatv2_lp_exp,
               gat_lp_exp,
               graphsage_lp_exp,
               ]
experiment_manager = ExperimentManager(experiments)

# %%
# camera ready
plt.close("all")
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "Time New Roman"
})
#models = ["GCN", "GAT", "MLP", "GATv2", "SGC", "GraphSAGE", "APPNP", "LP", "APPNP+LP","GCN+LP", "GAT+LP", "GATv2+LP","MLP+LP", "GraphSAGE+LP", "SGC+LP"]
models = ["MLP", "GCN", "APPNP", "SGC", "GAT", "GATv2", "GraphSAGE", "LP"]
#models = ["GCN"]
ylabel = r""
title = r"\textbf{Over-robustness} ($\mathcal{B}_{deg}$)" 
experiment_manager.plot_workshop(name="over-robustness-v2", attack="l2-weak", models=models, 
                        errorbars=True, title=title, spacing="even", ylabel=ylabel,
                        legend_loc="upper left", legend_cols=1, width = 0.8,
                        budget="deg+0", 
                        titlefont=23, tickfont=15, legendfont=13, 
                        xylabelfont=20, linewidth=3, markersize=10,
                        outside_legend=True, ylim=None, fontweight="bold",
                        tight_layout=True, handlelength=1.5, labelspacing = 0.3, 
                        K_l=[0.1, 0.5, 1.0, 1.5, 2.0, 3.0, 4.0, 5.0])
# Out:
# /nfs/homedirs/gosl/src/csbm/notebooks/robustness/utils.py:961: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([f"\\textbf{{{round(i, 2):.1f}}}" for i in ax.get_yticks()], fontsize=tickfont)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# camera ready
plt.close("all")
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "Time New Roman"
})
#models = ["GCN", "GAT", "GATv2", "SGC", "GraphSAGE", "APPNP", "LP", "APPNP+LP","GCN+LP", "GAT+LP", "GATv2+LP","MLP+LP", "GraphSAGE+LP", "SGC+LP"]
#models = ["MLP", "GCN", "APPNP", "SGC", "GAT", "GATv2", "GraphSAGE", "LP"]
models = ["GCN", "GCN+LP", "APPNP", "APPNP+LP", "GAT", "GAT+LP", "GATv2", "GATv2+LP"]
ylabel = r""
title = r"" 
experiment_manager.plot_workshop(name="over-robustness-v2", attack="GRBCD", models=models, 
                        errorbars=True, title=title, spacing="even", ylabel=ylabel,
                        legend_loc="upper left", legend_cols=1, width = 0.8,
                        budget="deg+0", 
                        titlefont=23, tickfont=15, legendfont=13, 
                        xylabelfont=20, linewidth=3, markersize=10,
                        outside_legend=True, ylim=None, fontweight="bold",
                        tight_layout=True, handlelength=1.5, labelspacing = 0.3, 
                        K_l=[0.1, 0.5, 1.0, 1.5, 2.0, 3.0, 4.0, 5.0])
# Out:
# /nfs/homedirs/gosl/src/csbm/notebooks/robustness/utils.py:961: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([f"\\textbf{{{round(i, 2):.1f}}}" for i in ax.get_yticks()], fontsize=tickfont)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#models = ["GCN", "GAT", "GATv2", "SGC", "MLP", "GraphSAGE", "APPNP", "LP", "APPNP+LP","GCN+LP", "GAT+LP", "GATv2+LP","MLP+LP", "GraphSAGE+LP", "SGC+LP"]
#models = ["SGC", "MLP"]#, "GATv2", "GATv2+LP", "GraphSAGE", "GraphSAGE+LP"]
models = ["APPNP"]
title = r"Adversarial Robustness $\frac{R_{f|g}}{R_{g}}$"
ylabel = "\% of optimal (Bayes) robustness achieved"
for budget in [1, 2, 3, 4, "deg+0", "deg+2"]:
    print(f"Budget: {budget}")
    df = experiment_manager.get_value_in_table(name="adversarial_error", attack="GRBCD", models=models, 
                            budget=budget, use_mean=True, use_std=False,
                            postfix="",
                            K_l=[0.1, 0.5, 1.0, 1.5, 2.0, 3.0, 4.0, 5.0])
    print(df.to_latex())
# Out:
# Budget: 1
# \begin{tabular}{lllllllll}
# \toprule
# {} &  0.1 &  0.5 &  1.0 &  1.5 &  2.0 &  3.0 &  4.0 &  5.0 \\
# \midrule
# APPNP &  4.4 &  3.5 &  2.2 &  1.6 &  0.7 &  0.1 &  0.2 &  0.2 \\
# \bottomrule
# \end{tabular}
#
# Budget: 2
# \begin{tabular}{lllllllll}
# \toprule
# {} &  0.1 &  0.5 &  1.0 &  1.5 &  2.0 &  3.0 &  4.0 &  5.0 \\
# \midrule
# APPNP &  9.2 &  7.3 &  4.2 &  3.2 &  1.1 &  0.2 &  0.4 &  0.3 \\
# \bottomrule
# \end{tabular}
#
# Budget: 3
# \begin{tabular}{lllllllll}
# \toprule
# {} &   0.1 &   0.5 &  1.0 &  1.5 &  2.0 &  3.0 &  4.0 &  5.0 \\
# \midrule
# APPNP &  13.3 &  10.5 &  5.9 &  4.6 &  1.8 &  0.2 &  0.6 &  0.5 \\
# \bottomrule
# \end{tabular}
#
# Budget: 4
# \begin{tabular}{lllllllll}
# \toprule
# {} &   0.1 &   0.5 &  1.0 &  1.5 &  2.0 &  3.0 &  4.0 &  5.0 \\
# \midrule
# APPNP &  15.8 &  12.5 &  7.6 &  6.0 &  2.7 &  0.2 &  0.9 &  0.7 \\
# \bottomrule
# \end{tabular}
#
# Budget: deg+0
# \begin{tabular}{lllllllll}
# \toprule
# {} &   0.1 &   0.5 &  1.0 &  1.5 &  2.0 &  3.0 &  4.0 &  5.0 \\
# \midrule
# APPNP &  15.6 &  11.1 &  7.4 &  6.9 &  3.0 &  0.3 &  1.2 &  1.0 \\
# \bottomrule
# \end{tabular}
#
# Budget: deg+2
# \begin{tabular}{lllllllll}
# \toprule
# {} &   0.1 &   0.5 &  1.0 &  1.5 &  2.0 &  3.0 &  4.0 &  5.0 \\
# \midrule
# APPNP &  19.1 &  14.6 &  9.4 &  8.7 &  4.1 &  0.3 &  2.3 &  2.1 \\
# \bottomrule
# \end{tabular}

# %%
#models = ["GCN", "GAT", "GATv2", "SGC", "MLP", "GraphSAGE", "APPNP", "LP", "APPNP+LP","GCN+LP", "GAT+LP", "GATv2+LP","MLP+LP", "GraphSAGE+LP", "SGC+LP"]
models = ["GCN", "GCN+LP", "APPNP", "APPNP+LP", "GAT", "GAT+LP", "GATv2", "GATv2+LP"]
title = r"Adversarial Robustness $\frac{R_{f|g}}{R_{g}}$"
ylabel = "\% of optimal (Bayes) robustness achieved"
df = experiment_manager.get_value_in_table(name="over-robustness-v2", attack="GRBCD", models=models, 
                        budget="deg+0",
                        K_l=[0.1, 0.5, 1.0, 1.5, 2.0, 3.0, 4.0, 5.0])
print(df.to_latex())
# Out:
# \begin{tabular}{lllllllll}
# \toprule
# {} &    0.1 &    0.5 &   1.0 &   1.5 &   2.0 &   3.0 &   4.0 &   5.0 \\
# \midrule
# GCN      &  11.9\% &   7.6\% &  3.9\% &  1.4\% &  0.6\% &  0.1\% &  0.1\% &  0.0\% \\
# APPNP    &  17.3\% &  13.1\% &  7.6\% &  5.0\% &  1.6\% &  0.1\% &  0.6\% &  0.6\% \\
# GAT      &  10.0\% &   9.2\% &  6.6\% &  3.7\% &  2.1\% &  0.7\% &  0.1\% &  0.1\% \\
# GATv2    &  10.0\% &   8.8\% &  6.5\% &  4.5\% &  2.7\% &  1.0\% &  0.4\% &  0.1\% \\
# GCN+LP   &   3.0\% &   1.9\% &  1.0\% &  0.6\% &  0.4\% &  0.2\% &  0.1\% &  0.1\% \\
# APPNP+LP &  10.5\% &   6.6\% &  3.9\% &  2.3\% &  0.3\% &  0.1\% &  0.4\% &  0.3\% \\
# GATv2+LP &   6.0\% &   4.1\% &  2.7\% &  2.3\% &  1.6\% &  0.8\% &  0.3\% &  0.1\% \\
# GAT+LP   &   5.1\% &   4.0\% &  2.7\% &  1.9\% &  1.4\% &  0.7\% &  0.2\% &  0.1\% \\
# \bottomrule
# \end{tabular}

# %%
#models = ["GCN", "GAT", "GATv2", "SGC", "MLP", "GraphSAGE", "APPNP", "LP", "APPNP+LP","GCN+LP", "GAT+LP", "GATv2+LP","MLP+LP", "GraphSAGE+LP", "SGC+LP"]
models = ["SGC", "MLP"]#, "GATv2", "GATv2+LP", "GraphSAGE", "GraphSAGE+LP"]
title = r"Adversarial Robustness $\frac{R_{f|g}}{R_{g}}$"
ylabel = "\% of optimal (Bayes) robustness achieved"
df = experiment_manager.get_value_in_table(name="over-robustness-v2", attack="GRBCD", models=models, 
                        budget="deg+0",
                        K_l=[0.1, 0.5, 1.0, 1.5, 2.0, 3.0, 4.0, 5.0])
print(df.to_latex())

# %%
# camera ready
plt.close("all")
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "Time New Roman"
})
models = ["MLP","GCN", "GAT", "GATv2", "SGC", "GraphSAGE", "APPNP", "LP", "APPNP+LP","GCN+LP", "GAT+LP", "GATv2+LP","MLP+LP", "GraphSAGE+LP", "SGC+LP"]
#models = ["GCN", "GCN+LP", "APPNP", "APPNP+LP", "GAT", "GAT+LP", "GATv2", "GATv2+LP"]
ylabel = r"$\mathbf{R_f}$"
title = r"\textbf{Classic Adversarial Robustness:} $\mathbf{R_{f}}$" 
experiment_manager.plot_workshop(name="f_wrt_y", attack="l2", models=models, 
                        errorbars=True, title=title, spacing="even", ylabel=ylabel,
                        legend_loc="upper left", legend_cols=1, width = 0.8,
                        budget="deg+0", 
                        titlefont=20, tickfont=15, legendfont=13, 
                        xylabelfont=17, linewidth=3, markersize=10,
                        outside_legend=True, ylim=None, fontweight="bold",
                        tight_layout=True, handlelength=1.5, labelspacing = 0.3, 
                        K_l=[0.1, 0.5, 1.0, 1.5, 2.0, 3.0, 4.0, 5.0])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close("all")
#models = ["GCN", "GAT", "GATv2", "SGC", "MLP", "GraphSAGE", "APPNP", "LP", "APPNP+LP","GCN+LP", "GAT+LP", "GATv2+LP","MLP+LP", "GraphSAGE+LP", "SGC+LP"]
models = ["GCN", "GCN+LP", "APPNP", "APPNP+LP", "GAT", "GAT+LP", "GATv2", "GATv2+LP"]
ylabel = r"$\mathbf{F_1^{rob}}$"
title = r"\textbf{Harmonic Mean of } $\mathbf{1-R^{over}}$ \textbf{and} $\mathbf{R^{adv}}$" #$\mathbf{R^{over}}$ 
experiment_manager.plot_f1(name="f1-robustness-v2", attack_overrobustness="l2-weak", 
                        attack_advrobustness="GRBCD", models=models, 
                        errorbars=True, title=title, spacing="even", ylabel=ylabel,
                        legend_loc="upper left", width = 0.8,
                        budget="deg+0", titlefont=15, tickfont=12, legendfont=13, 
                        xylabelfont=14, handlelength=1.5, labelspacing = 0.3, 
                        K_l=[0.1, 0.5, 1.0, 1.5, 2.0, 3.0, 4.0, 5.0])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close("all")
models = ["GCN", "GAT", "GATv2", "SGC", "MLP", "GraphSAGE", "APPNP", "LP", "APPNP+LP","GCN+LP", "GAT+LP", "GATv2+LP","MLP+LP", "GraphSAGE+LP", "SGC+LP"]
#models = ["GCN", "GAT", "GATv2", "SGC", "MLP", "GraphSAGE", "APPNP", "LP"]
title = r"\textbf{Validation accuracy}"
ylabel = r"\textbf{Accuracy"
experiment_manager.plot_workshop(name="validation-accuracy", attack="l2", models=models, 
                        errorbars=True, title=title, ylabel=ylabel,
                        spacing="even", legend_loc="lower right", legend_cols=1,
                        titlefont=15, xylabelfont=13, tickfont=12, outside_legend=False,
                        bbox_to_anchor=(1,0), width=1, legendfont=13, handlelength=2,
                        labelspacing=0.3, borderpad=0.3,
                        K_l=[0.1, 0.5, 1.0, 1.5, 2.0, 3.0, 4.0, 5.0])
# Out:
# /nfs/homedirs/gosl/src/csbm/notebooks/robustness/utils.py:961: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([f"\\textbf{{{round(i, 2):.1f}}}" for i in ax.get_yticks()], fontsize=tickfont)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close("all")
title = r"\textbf{Validation accuracy}"
ylabel = r"\textbf{Accuracy}"
experiment_manager.plot_workshop(name="validation-accuracy", attack="l2", models=models, 
                        errorbars=True, title=title, spacing="even", ylabel=ylabel,
                        legend_loc="upper left", legend_cols=1, width = 0.8,
                        budget="deg+0", 
                        titlefont=20, tickfont=15, legendfont=13, 
                        xylabelfont=17, linewidth=2, markersize=10,
                        outside_legend=True, ylim=None, fontweight="bold",
                        tight_layout=True, handlelength=1.5, labelspacing = 0.3, 
                        K_l=[0.1, 0.5, 1.0, 1.5, 2.0, 3.0, 4.0, 5.0])
# Out:
# /nfs/homedirs/gosl/src/csbm/notebooks/robustness/utils.py:961: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([f"\\textbf{{{round(i, 2):.1f}}}" for i in ax.get_yticks()], fontsize=tickfont)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
