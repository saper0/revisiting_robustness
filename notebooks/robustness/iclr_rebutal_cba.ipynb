# %%
# Reload modules automatically
# https://ipython.readthedocs.io/en/stable/config/extensions/autoreload.html
# %load_ext autoreload
# %autoreload 2
# %matplotlib widget

from utils import ExperimentManager

import matplotlib.pyplot as plt
import numpy as np

gcn_exp = dict(
    label = "GCN",
    collection = "rob_cba_gcn",
    start_id = 1,
    end_id = 400,
    n_seeds = 10, 
)
appnp_exp = dict(
    label = "APPNP",
    collection = "rob_cba_appnp",
    start_id = 1,
    end_id = 400,
    n_seeds = 10,
)
gat_exp = dict(
    label = "GAT",
    collection = "rob_cba_gat",
    start_id = 1,
    end_id = 400,
    n_seeds = 10,
)
lp_exp = dict(
    label = "LP",
    collection = "rob_csbm_lp",
    start_id = 1,
    end_id = 400,
    n_seeds = 10,
)
mlp_exp = dict(
    label = "MLP",
    collection = "rob_cba_mlp",
    start_id = 1,
    end_id = 400,
    n_seeds = 10,
)
gcn_lp_exp = dict(
    label = "GCN+LP",
    collection = "rob_cba_gcn_lp",
    start_id = 1,
    end_id = 400,
    n_seeds = 10, 
)
appnp_lp_exp = dict(
    label = "APPNP+LP",
    collection = "rob_cba_appnp_lp",
    start_id = 1,
    end_id = 400,
    n_seeds = 10,
)
gat_lp_exp = dict(
    label = "GAT+LP",
    collection = "rob_cba_gat_lp",
    start_id = 1,
    end_id = 400,
    n_seeds = 10,
)
mlp_lp_exp = dict(
    label = "MLP+LP",
    collection = "rob_cba_mlp_lp",
    start_id = 1,
    end_id = 400,
    n_seeds = 10,
)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#This notebook is used to analyse the over- and under-robustness of models. 
Ks = [0.1, 0.5, 1.0, 1.5, 2.0, 3.0, 4.0, 5.0]

experiments = [#mlp_exp,
               gcn_exp,
               appnp_exp,
               gat_exp, 
               #lp_exp, 
               #mlp_lp_exp,
               gcn_lp_exp,
               appnp_lp_exp, 
               gat_lp_exp,
               ]
experiment_manager = ExperimentManager(experiments)

# %%
plt.close("all")
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "Time New Roman"
})
models = ["GCN", "APPNP", "SGC", "GAT", "GATv2", "GraphSAGE"]
ylabel = r"\textbf{Structure Perturbations}"
K = 1.5
title = r"\begin{center}\textbf{Average Structure Perturbations}\\\textbf{until GNN-Prediction Changes}\end{center}"
bayes_label = r"\begin{flushleft}\textbf{Semantic}\\\textbf{Boundary}\end{flushleft}"
experiment_manager.starplot_workshop(name="f_wrt_y", attack="l2-weak", models=models, 
                            max_degree=8, xyfontsize=15, ticksize=15, legendsize=13,
                            logplot=True, titlefont=17, linewidth=2.5, markersize=8,
                            K=K, invert_axis=False,
                            errorbars=True, 
                            title=title, 
                            ylabel=ylabel,
                            bayes_label = bayes_label)
# Out:
# /nfs/homedirs/gosl/src/csbm/notebooks/robustness/utils.py:1685: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs.set_xticklabels([int(i) for i in axs.get_xticks()],
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# camera ready
plt.close("all")
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "Time New Roman"
})
#models = ["GCN", "GAT", "GATv2", "SGC", "MLP", "GraphSAGE", "APPNP", "LP", "APPNP+LP","GCN+LP", "GAT+LP", "GATv2+LP","MLP+LP", "GraphSAGE+LP", "SGC+LP"]
models = ["GCN", "GAT", "APPNP", "GCN+LP", "GAT+LP", "APPNP+LP"]
#models = ["GCN"]
ylabel = r""
title = r"\textbf{Over-robustness:} $\mathbf{R^{over}}$" #$\mathbf{R^{over}}$ 
experiment_manager.plot_workshop(name="over-robustness-v2", attack="l2-weak", models=models, 
                        errorbars=True, title=title, spacing="even", ylabel=ylabel,
                        legend_loc="upper right", legend_cols=1, width = 1,
                        budget="deg+0", titlefont=23, tickfont=15, legendfont=15, 
                        xylabelfont=17, linewidth=4, markersize=10,
                        outside_legend=False, ylim=0.5, fontweight="normal",
                        K_l=[0.1, 0.5, 1.0, 1.5, 2.0, 3.0, 4.0, 5.0])
# Out:
# /nfs/homedirs/gosl/src/csbm/notebooks/robustness/utils.py:943: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([f"\\textbf{{{round(i, 2):.1f}}}" for i in ax.get_yticks()], fontsize=tickfont)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# camera ready
plt.close("all")
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "Time New Roman"
})
#models = ["GCN", "GAT", "GATv2", "SGC", "MLP", "GraphSAGE", "APPNP", "LP", "APPNP+LP","GCN+LP", "GAT+LP", "GATv2+LP","MLP+LP", "GraphSAGE+LP", "SGC+LP"]
models = ["GCN", "GAT", "APPNP", "GCN+LP", "GAT+LP", "APPNP+LP"]
#models = ["GCN"]
ylabel = r""
title = r"\textbf{Over-robustness:} $\mathbf{R^{over}}$" #$\mathbf{R^{over}}$ 
experiment_manager.plot_workshop(name="over-robustness-v2", attack="nettack", models=models, 
                        errorbars=True, title=title, spacing="even", ylabel=ylabel,
                        legend_loc="upper right", legend_cols=1, width = 1,
                        budget="deg+0", titlefont=23, tickfont=15, legendfont=15, 
                        xylabelfont=17, linewidth=4, markersize=10,
                        outside_legend=False, ylim=0.5, fontweight="normal",
                        K_l=[0.1, 0.5, 1.0, 1.5, 2.0, 3.0, 4.0, 5.0])
# Out:
# /nfs/homedirs/gosl/src/csbm/notebooks/robustness/utils.py:943: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([f"\\textbf{{{round(i, 2):.1f}}}" for i in ax.get_yticks()], fontsize=tickfont)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# camera ready
plt.close("all")
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "Time New Roman"
})
#models = ["GCN", "GAT", "GATv2", "SGC", "MLP", "GraphSAGE", "APPNP", "LP", "APPNP+LP","GCN+LP", "GAT+LP", "GATv2+LP","MLP+LP", "GraphSAGE+LP", "SGC+LP"]
models = ["GCN", "GAT", "APPNP", "GCN+LP", "GAT+LP", "APPNP+LP"]
#models = ["GCN"]
ylabel = r""
title = r"\textbf{Over-robustness:} $\mathbf{R^{over}}$" #$\mathbf{R^{over}}$ 
experiment_manager.plot_workshop(name="over-robustness-v2", attack="nettack_power_law_test", models=models, 
                        errorbars=True, title=title, spacing="even", ylabel=ylabel,
                        legend_loc="upper right", legend_cols=1, width = 1,
                        budget="deg+0", titlefont=23, tickfont=15, legendfont=15, 
                        xylabelfont=17, linewidth=4, markersize=10,
                        outside_legend=False, ylim=0.5, fontweight="normal",
                        K_l=[0.1, 0.5, 1.0, 1.5, 2.0, 3.0, 4.0, 5.0])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
