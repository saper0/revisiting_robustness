# %%
# Reload modules automatically
# https://ipython.readthedocs.io/en/stable/config/extensions/autoreload.html
# %load_ext autoreload
# %autoreload 2

# %%
from utils import ExperimentManager

# %%
#This notebook is used to analyse the over- and under-robustness of models. 
Ks = [0.1, 0.5, 1.0, 1.5, 2.0, 5.0]

gcn_exp = dict(
    label = "GCN",
    start_id = 3565,
    end_id = 3684,
    n_seeds = 10,
)
appnp_exp = dict(
    label = "APPNP",
    start_id = 3685,
    end_id = 3804,
    n_seeds = 10,
)
gat_exp = dict(
    label = "GAT",
    start_id = 3805,
    end_id = 3924,
    n_seeds = 10,
)
lp_exp = dict(
    label = "LP",
    start_id = 3925,
    end_id = 4044,
    n_seeds = 10,
)
gcn_lp_exp = dict(
    label = "GCN+LP",
    start_id = 4045,
    end_id = 4164,
    n_seeds = 10,
)
appnp_lp_exp = dict(
    label = "APPNP+LP",
    start_id = 4165,
    end_id = 4284,
    n_seeds = 10,
)
gat_lp_exp = dict(
    label = "GAT+LP",
    start_id = 4285,
    end_id = 4404,
    n_seeds = 10,
)

experiments = [gcn_exp, appnp_exp, gat_exp, lp_exp, gcn_lp_exp, appnp_lp_exp, gat_lp_exp]
experiment_manager = ExperimentManager(experiments)
# Out:
# GCN on K=0.1 has 79.8+-1.7% trn acc and 67.9+-3.4% val acc.
# GCN on K=0.1 has 79.4+-1.5% trn acc and 68.1+-2.2% val acc.
# GCN on K=0.5 has 82.7+-2.9% trn acc and 75.4+-1.9% val acc.
# GCN on K=0.5 has 82.2+-2.8% trn acc and 75.0+-2.6% val acc.
# GCN on K=1.0 has 85.4+-2.4% trn acc and 84.1+-3.1% val acc.
# GCN on K=1.0 has 85.5+-2.5% trn acc and 83.7+-2.8% val acc.
# GCN on K=1.5 has 89.8+-1.3% trn acc and 89.1+-1.9% val acc.
# GCN on K=1.5 has 89.8+-1.2% trn acc and 89.2+-2.0% val acc.
# GCN on K=2.0 has 92.3+-1.2% trn acc and 92.5+-1.3% val acc.
# GCN on K=2.0 has 92.2+-1.2% trn acc and 92.2+-1.5% val acc.
# GCN on K=5.0 has 96.0+-0.7% trn acc and 96.0+-1.7% val acc.
# GCN on K=5.0 has 96.0+-0.7% trn acc and 96.0+-1.7% val acc.
# APPNP on K=0.1 has 86.0+-6.2% trn acc and 73.6+-6.0% val acc.
# APPNP on K=0.1 has 86.5+-6.2% trn acc and 74.1+-5.8% val acc.
# APPNP on K=0.5 has 89.2+-4.1% trn acc and 79.3+-4.4% val acc.
# APPNP on K=0.5 has 89.1+-4.0% trn acc and 79.5+-4.7% val acc.
# APPNP on K=1.0 has 90.1+-1.5% trn acc and 86.9+-1.8% val acc.
# APPNP on K=1.0 has 90.4+-1.7% trn acc and 87.1+-1.7% val acc.
# APPNP on K=1.5 has 92.1+-2.2% trn acc and 90.5+-1.4% val acc.
# APPNP on K=1.5 has 92.1+-2.2% trn acc and 90.5+-1.4% val acc.
# APPNP on K=2.0 has 94.0+-0.9% trn acc and 93.5+-1.0% val acc.
# APPNP on K=2.0 has 94.0+-0.9% trn acc and 93.6+-1.0% val acc.
# APPNP on K=5.0 has 98.7+-0.6% trn acc and 98.5+-0.8% val acc.
# APPNP on K=5.0 has 98.7+-0.6% trn acc and 98.5+-0.8% val acc.
# GAT on K=0.1 has 87.9+-2.3% trn acc and 76.3+-3.1% val acc.
# GAT on K=0.1 has 88.9+-3.3% trn acc and 76.0+-3.7% val acc.
# GAT on K=0.5 has 86.5+-1.9% trn acc and 79.6+-2.7% val acc.
# GAT on K=0.5 has 87.4+-1.2% trn acc and 80.1+-2.6% val acc.
# GAT on K=1.0 has 89.6+-1.2% trn acc and 85.4+-2.1% val acc.
# GAT on K=1.0 has 87.8+-2.9% trn acc and 84.7+-2.4% val acc.
# GAT on K=1.5 has 93.3+-1.8% trn acc and 89.0+-1.8% val acc.
# GAT on K=1.5 has 93.4+-1.9% trn acc and 89.3+-1.4% val acc.
# GAT on K=2.0 has 93.5+-1.7% trn acc and 92.7+-1.8% val acc.
# GAT on K=2.0 has 93.2+-1.6% trn acc and 92.5+-1.7% val acc.
# GAT on K=5.0 has 96.4+-1.5% trn acc and 96.1+-1.7% val acc.
# GAT on K=5.0 has 96.3+-1.5% trn acc and 96.0+-2.1% val acc.
# LP on K=0.1 has 99.9+-0.1% trn acc and 87.2+-1.8% val acc.
# LP on K=0.1 has 99.9+-0.1% trn acc and 87.2+-1.8% val acc.
# LP on K=0.5 has 99.9+-0.1% trn acc and 87.2+-1.8% val acc.
# LP on K=0.5 has 99.9+-0.1% trn acc and 87.2+-1.8% val acc.
# LP on K=1.0 has 99.9+-0.1% trn acc and 87.2+-1.8% val acc.
# LP on K=1.0 has 99.9+-0.1% trn acc and 87.2+-1.8% val acc.
# LP on K=1.5 has 99.9+-0.1% trn acc and 87.2+-1.8% val acc.
# LP on K=1.5 has 99.9+-0.1% trn acc and 87.2+-1.8% val acc.
# LP on K=2.0 has 99.9+-0.1% trn acc and 87.2+-1.8% val acc.
# LP on K=2.0 has 99.9+-0.1% trn acc and 87.2+-1.8% val acc.
# LP on K=5.0 has 99.9+-0.1% trn acc and 87.2+-1.8% val acc.
# LP on K=5.0 has 99.9+-0.1% trn acc and 87.2+-1.8% val acc.
# GCN+LP on K=0.1 has 99.9+-0.1% trn acc and 85.0+-2.0% val acc.
# GCN+LP on K=0.1 has 99.9+-0.1% trn acc and 84.8+-2.0% val acc.
# GCN+LP on K=0.5 has 99.9+-0.1% trn acc and 87.0+-1.9% val acc.
# GCN+LP on K=0.5 has 99.9+-0.1% trn acc and 86.9+-1.9% val acc.
# GCN+LP on K=1.0 has 99.9+-0.1% trn acc and 89.4+-1.7% val acc.
# GCN+LP on K=1.0 has 99.9+-0.1% trn acc and 89.3+-1.7% val acc.
# GCN+LP on K=1.5 has 99.8+-0.2% trn acc and 90.8+-1.6% val acc.
# GCN+LP on K=1.5 has 99.8+-0.1% trn acc and 90.7+-1.6% val acc.
# GCN+LP on K=2.0 has 99.8+-0.1% trn acc and 92.5+-1.8% val acc.
# GCN+LP on K=2.0 has 99.8+-0.2% trn acc and 92.7+-1.6% val acc.
# GCN+LP on K=5.0 has 99.7+-0.2% trn acc and 94.9+-1.4% val acc.
# GCN+LP on K=5.0 has 99.7+-0.2% trn acc and 94.9+-1.4% val acc.
# APPNP+LP on K=0.1 has 99.9+-0.1% trn acc and 83.4+-3.1% val acc.
# APPNP+LP on K=0.1 has 99.9+-0.1% trn acc and 83.8+-3.5% val acc.
# APPNP+LP on K=0.5 has 99.9+-0.1% trn acc and 86.0+-1.9% val acc.
# APPNP+LP on K=0.5 has 99.9+-0.1% trn acc and 85.6+-2.4% val acc.
# APPNP+LP on K=1.0 has 99.8+-0.1% trn acc and 89.3+-1.6% val acc.
# APPNP+LP on K=1.0 has 99.8+-0.1% trn acc and 89.4+-1.4% val acc.
# APPNP+LP on K=1.5 has 99.8+-0.2% trn acc and 91.7+-1.5% val acc.
# APPNP+LP on K=1.5 has 99.8+-0.2% trn acc and 91.7+-1.5% val acc.
# APPNP+LP on K=2.0 has 99.8+-0.2% trn acc and 94.0+-1.6% val acc.
# APPNP+LP on K=2.0 has 99.8+-0.2% trn acc and 94.0+-1.6% val acc.
# APPNP+LP on K=5.0 has 99.7+-0.2% trn acc and 97.5+-1.3% val acc.
# APPNP+LP on K=5.0 has 99.7+-0.2% trn acc and 97.5+-1.3% val acc.
# GAT+LP on K=0.1 has 99.9+-0.1% trn acc and 84.9+-1.5% val acc.
# GAT+LP on K=0.1 has 99.9+-0.1% trn acc and 87.0+-2.4% val acc.
# GAT+LP on K=0.5 has 99.9+-0.1% trn acc and 87.6+-2.0% val acc.
# GAT+LP on K=0.5 has 99.9+-0.1% trn acc and 88.0+-1.6% val acc.
# GAT+LP on K=1.0 has 99.9+-0.1% trn acc and 89.5+-2.0% val acc.
# GAT+LP on K=1.0 has 99.9+-0.1% trn acc and 89.4+-2.0% val acc.
# GAT+LP on K=1.5 has 99.8+-0.1% trn acc and 90.7+-1.6% val acc.
# GAT+LP on K=1.5 has 99.8+-0.1% trn acc and 90.7+-1.6% val acc.
# GAT+LP on K=2.0 has 99.8+-0.2% trn acc and 92.7+-2.0% val acc.
# GAT+LP on K=2.0 has 99.8+-0.2% trn acc and 92.9+-2.0% val acc.
# GAT+LP on K=5.0 has 99.8+-0.2% trn acc and 94.7+-1.6% val acc.
# GAT+LP on K=5.0 has 99.8+-0.2% trn acc and 94.9+-1.7% val acc.

# %%
models = ["GCN", "GCN+LP"]
experiment_manager.plot_overrobustness(models, Ks)
