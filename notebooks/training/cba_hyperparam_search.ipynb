# %%
# Reload modules automatically
# https://ipython.readthedocs.io/en/stable/config/extensions/autoreload.html
# %load_ext autoreload
# %autoreload 2

# %%
import importlib
import utils
import pandas as pd

# %% [markdown]
# # GCN

# %%
start_id = 1
end_id = 2880
n_seeds = 10
K_l = [0.1, 0.5, 1, 1.5, 2, 3, 4, 5]
hyperparams = ["dropout", "lr", "weight_decay"]
collection="trn_cba_gcn"
utils.get_best_hyperparams(start_id, end_id, n_seeds, hyperparams, K_l, 
                           collection, use_seeds=10)
# Out:
#               ValLoss           TrnLoss            ValAcc            TrnAcc  \
# 0.1  0.6243 +- 0.0274  0.5032 +- 0.0458  0.6655 +- 0.0280  0.7539 +- 0.0297
# 0.5  0.5387 +- 0.0405  0.4545 +- 0.0606  0.7260 +- 0.0388  0.7880 +- 0.0361
# 1.0  0.3961 +- 0.0465  0.3803 +- 0.0732  0.8225 +- 0.0372  0.8340 +- 0.0343
# 1.5  0.2878 +- 0.0421  0.2961 +- 0.0674  0.8825 +- 0.0287  0.8821 +- 0.0278
# 2.0  0.2211 +- 0.0396  0.2415 +- 0.0202  0.9090 +- 0.0226  0.9074 +- 0.0101
# 3.0  0.1581 +- 0.0318  0.1687 +- 0.0314  0.9315 +- 0.0221  0.9339 +- 0.0119
# 4.0  0.1312 +- 0.0346  0.1450 +- 0.0356  0.9510 +- 0.0128  0.9451 +- 0.0110
# 5.0  0.1184 +- 0.0333  0.1267 +- 0.0291  0.9590 +- 0.0126  0.9495 +- 0.0089
#
#      dropout    lr  weight_decay    id
# 0.1      0.5  0.10        0.0010   251
# 0.5      0.5  0.10        0.0010   611
# 1.0      0.5  0.10        0.0010   971
# 1.5      0.5  0.10        0.0010  1331
# 2.0      0.0  0.01        0.0001  1491
# 3.0      0.3  0.10        0.0100  1921
# ...

# %%
start_id = 1
end_id = 6480
n_seeds = 30
K = 0.1
hyperparams = ["dropout", "lr", "weight_decay"]
collection="trn_csbm_gcn"
exp_loader = utils.ExperimentLoader(collection = collection)
experiments = exp_loader.load_experiments(start_id, end_id, n_seeds, K)
print(experiments[0].validation_loss_l)
# Out:
# [0.6567577123641968, 0.5980815291404724, 0.57259202003479, 0.6241163611412048, 0.6034643650054932, 0.5516995191574097, 0.5971602201461792, 0.5991422533988953, 0.6272956132888794, 0.5734785199165344, 0.608515202999115, 0.6427104473114014, 0.5773911476135254, 0.6777182817459106, 0.6844530701637268, 0.5839795470237732, 0.556592583656311, 0.6219276785850525, 0.6010706424713135, 0.7045059204101562, 0.5935205817222595, 0.7119748592376709, 0.5773491263389587, 0.6490527987480164, 0.6875882148742676, 0.5870239734649658, 0.5749179124832153, 0.6553679704666138, 0.6944940090179443, 0.6371374130249023]

# %% [markdown]
# # GAT

# %%
start_id = 1
end_id = 19440
n_seeds = 30
K_l = [0.1, 0.5, 1, 1.5, 2, 3, 4, 5]
hyperparams = ["dropout", "dropout_neighbourhood", "lr", "weight_decay"]
collection="trn_csbm_gat"
utils.get_best_hyperparams(start_id, end_id, n_seeds, hyperparams, K_l, 
                           collection, use_seeds=10)
# Out:
#               ValLoss           TrnLoss            ValAcc            TrnAcc  \
# 0.1  0.4829 +- 0.0314  0.5096 +- 0.0417  0.7875 +- 0.0296  0.7410 +- 0.0256
# 0.5  0.4455 +- 0.0489  0.4094 +- 0.0218  0.8060 +- 0.0306  0.7877 +- 0.0149
# 1.0  0.3525 +- 0.0231  0.4709 +- 0.0201  0.8590 +- 0.0234  0.7684 +- 0.0116
# 1.5  0.2602 +- 0.0345  0.4430 +- 0.0410  0.8970 +- 0.0212  0.7911 +- 0.0204
# 2.0  0.2013 +- 0.0301  0.3886 +- 0.0350  0.9205 +- 0.0171  0.8062 +- 0.0192
# 3.0  0.1311 +- 0.0294  0.3261 +- 0.0312  0.9535 +- 0.0116  0.8331 +- 0.0201
# 4.0  0.0894 +- 0.0241  0.3106 +- 0.0499  0.9575 +- 0.0112  0.8439 +- 0.0251
# 5.0  0.0738 +- 0.0213  0.3378 +- 0.1213  0.9630 +- 0.0155  0.8465 +- 0.0382
#
#      dropout  dropout_neighbourhood    lr  weight_decay     id
# 0.1      0.0                    0.6  0.10        0.0001    601
# 0.5      0.0                    0.3  0.01        0.0001   2851
# 1.0      0.0                    0.3  0.10        0.0010   5161
# ...

# %% [markdown]
# # APPNP

# %%
start_id = 1
end_id = 14580
n_seeds = 30
K_l = [0.1, 0.5, 1, 1.5, 2, 5]
hyperparams = ["dropout", "alpha", "lr", "weight_decay"]
collection="trn_csbm_appnp"
utils.get_best_hyperparams(start_id, end_id, n_seeds, hyperparams, K_l, 
                           collection)
# Out:
#               ValLoss           TrnLoss            ValAcc            TrnAcc  \
# 0.1  0.5246 +- 0.0732  0.2576 +- 0.1388  0.7580 +- 0.0575  0.8979 +- 0.0977
# 0.5  0.4740 +- 0.0629  0.2261 +- 0.0712  0.8037 +- 0.0285  0.9180 +- 0.0352
# 1.0  0.3619 +- 0.0589  0.2151 +- 0.0609  0.8598 +- 0.0222  0.9204 +- 0.0278
# 1.5  0.2681 +- 0.0468  0.2162 +- 0.0733  0.9000 +- 0.0203  0.9204 +- 0.0343
# 2.0  0.1882 +- 0.0373  0.1840 +- 0.0449  0.9278 +- 0.0204  0.9296 +- 0.0206
# 5.0  0.0286 +- 0.0228  0.0432 +- 0.0124  0.9895 +- 0.0095  0.9850 +- 0.0053
#
#      dropout  alpha    lr  weight_decay     id
# 0.1      0.0   0.05  0.10         0.001     31
# 0.5      0.0   0.05  0.10         0.001   2461
# 1.0      0.0   0.05  0.10         0.001   4891
# 1.5      0.0   0.10  0.01         0.001   7681
# 2.0      0.0   0.20  0.01         0.001  10381
# 5.0      0.0   0.20  0.10         0.010  12691

# %%
start_id = 1
end_id = 19440
n_seeds = 30
K_l = [0.1, 0.5, 1, 1.5, 2, 3, 4, 5]
hyperparams = ["dropout", "alpha", "lr", "weight_decay"]
collection="trn_csbm_appnp"
utils.get_best_hyperparams(start_id, end_id, n_seeds, hyperparams, K_l, 
                           collection, use_seeds=10)
# Out:
#               ValLoss           TrnLoss            ValAcc            TrnAcc  \
# 0.1  0.5073 +- 0.0451  0.2260 +- 0.0412  0.7770 +- 0.0330  0.9206 +- 0.0196
# 0.5  0.4411 +- 0.0453  0.2349 +- 0.0667  0.8120 +- 0.0272  0.9096 +- 0.0345
# 1.0  0.3348 +- 0.0346  0.2489 +- 0.0545  0.8630 +- 0.0224  0.9046 +- 0.0246
# 1.5  0.2506 +- 0.0366  0.2098 +- 0.0543  0.9035 +- 0.0172  0.9189 +- 0.0222
# 2.0  0.1811 +- 0.0274  0.1842 +- 0.0372  0.9295 +- 0.0127  0.9311 +- 0.0161
# 3.0  0.0843 +- 0.0308  0.0900 +- 0.0317  0.9685 +- 0.0145  0.9671 +- 0.0128
# 4.0  0.0449 +- 0.0246  0.0547 +- 0.0150  0.9850 +- 0.0095  0.9810 +- 0.0051
# 5.0  0.0309 +- 0.0216  0.0376 +- 0.0109  0.9885 +- 0.0084  0.9871 +- 0.0057
#
#      dropout  alpha    lr  weight_decay     id
# 0.1      0.0   0.05  0.10        0.0010     31
# 0.5      0.0   0.05  0.10        0.0010   2461
# 1.0      0.0   0.05  0.10        0.0010   4891
# 1.5      0.0   0.05  0.10        0.0010   7321
# ...

# %%
start_id = 1
end_id = 19440
n_seeds = 30
hyperparams = ["dropout", "alpha", "lr", "weight_decay"]
collection="trn_csbm_appnp"
utils.get_best_hyperparams(start_id, end_id, n_seeds, hyperparams, 1.5, 
                           collection, use_seeds=10)
# Out:
#                ValLoss                                   TrnLoss  \
# 7321  0.2506 +- 0.0366                          0.2098 +- 0.0543
# 7771  0.2516 +- 0.0302                          0.1721 +- 0.0436
# 7411  0.2527 +- 0.0361                          0.2075 +- 0.0583
# 7801  0.2536 +- 0.0331                          0.1852 +- 0.0528
# 7681  0.2536 +- 0.0314                          0.2219 +- 0.0643
# ...                ...                                       ...
# 8311  0.6710 +- 0.0079                  50038.3308 +- 72821.8269
# 9361  0.6711 +- 0.0090  1744604140092.3909 +- 3120544569358.1846
# 9151  0.6757 +- 0.0108  3184815004397.8921 +- 6360459489828.3008
# 9121  0.6759 +- 0.0113  3194512647957.9424 +- 6382904788862.5205
# 9091  0.6783 +- 0.0108  2123168475098.4187 +- 5054272993451.9355
#
#                 ValAcc            TrnAcc  dropout  alpha     lr  weight_decay
# 7321  0.9035 +- 0.0172  0.9189 +- 0.0222      0.0   0.05  0.100        0.0010
# ...

# %% [markdown]
# # MLP

# %%
start_id = 1
end_id = 8640
n_seeds = 10
K_l = [0.1, 0.5, 1, 1.5, 2, 3, 4, 5]
hyperparams = ["hidden_channels", "dropout", "lr", "weight_decay"]
collection="trn_csbm_mlp"
utils.get_best_hyperparams(start_id, end_id, n_seeds, hyperparams, K_l, 
                           collection)
# Out:
#               ValLoss           TrnLoss            ValAcc            TrnAcc  \
# 0.1  0.6721 +- 0.0110  0.7339 +- 0.0568  0.5780 +- 0.0245  0.5487 +- 0.0300
# 0.5  0.6424 +- 0.0187  0.6493 +- 0.0114  0.6305 +- 0.0328  0.6094 +- 0.0185
# 1.0  0.5596 +- 0.0273  0.6116 +- 0.0370  0.7075 +- 0.0325  0.6730 +- 0.0161
# 1.5  0.4466 +- 0.0321  0.5355 +- 0.0578  0.7905 +- 0.0247  0.7402 +- 0.0134
# 2.0  0.3342 +- 0.0372  0.3221 +- 0.0252  0.8545 +- 0.0288  0.8629 +- 0.0157
# 3.0  0.1510 +- 0.0258  0.2704 +- 0.0799  0.9375 +- 0.0175  0.8955 +- 0.0166
# 4.0  0.0439 +- 0.0167  0.1382 +- 0.0413  0.9825 +- 0.0098  0.9522 +- 0.0064
# 5.0  0.0051 +- 0.0065  0.2148 +- 0.1531  0.9990 +- 0.0020  0.9796 +- 0.0036
#
#      hidden_channels  dropout    lr  weight_decay    id
# 0.1              256      0.5  0.10        0.0001  1011
# 0.5              256      0.3  0.10        0.0100  1981
# 1.0              256      0.3  0.10        0.0100  3061
# 1.5              256      0.3  0.10        0.0100  4141
# ...

# %% [markdown]
# # GraphSAGE

# %%
start_id = 1
end_id = 6480
n_seeds = 10
K_l = [0.1, 0.5, 1, 1.5, 2, 3, 4, 5]
hyperparams = ["hidden_channels", "dropout", "lr", "weight_decay"]
collection="trn_csbm_sage"
utils.get_best_hyperparams(start_id, end_id, n_seeds, hyperparams, K_l, 
                           collection)
# Out:
#               ValLoss           TrnLoss            ValAcc            TrnAcc  \
# 0.1  0.5619 +- 0.0294  0.4192 +- 0.0290  0.7190 +- 0.0345  0.8080 +- 0.0158
# 0.5  0.5020 +- 0.0271  0.4157 +- 0.0202  0.7630 +- 0.0208  0.8195 +- 0.0138
# 1.0  0.3840 +- 0.0201  0.3281 +- 0.0795  0.8370 +- 0.0203  0.8590 +- 0.0387
# 1.5  0.2793 +- 0.0309  0.2434 +- 0.0251  0.8920 +- 0.0225  0.8967 +- 0.0108
# 2.0  0.1911 +- 0.0311  0.2327 +- 0.0861  0.9295 +- 0.0165  0.9107 +- 0.0259
# 3.0  0.0823 +- 0.0318  0.0727 +- 0.0179  0.9700 +- 0.0134  0.9744 +- 0.0068
# 4.0  0.0246 +- 0.0176  0.1942 +- 0.3321  0.9880 +- 0.0090  0.9817 +- 0.0071
# 5.0  0.0020 +- 0.0032  0.1928 +- 0.1339  0.9995 +- 0.0015  0.9892 +- 0.0038
#
#      hidden_channels  dropout    lr  weight_decay    id
# 0.1              128      0.3  0.10         0.001   371
# 0.5               64      0.3  0.10         0.001   911
# 1.0               64      0.3  0.01         0.001  1751
# 1.5              128      0.3  0.10         0.001  2801
# ...

# %%
start_id = 1
end_id = 6480
n_seeds = 10
K_l = [0.1, 0.5, 1, 1.5, 2, 3, 4, 5]
hyperparams = ["hidden_channels", "dropout", "lr", "weight_decay"]
collection="trn_csbm_sage"
utils.get_best_hyperparams(start_id, end_id, n_seeds, hyperparams, K_l, 
                           collection)
# Out:
#               ValLoss           TrnLoss            ValAcc            TrnAcc  \
# 0.1  0.5674 +- 0.0286  0.4402 +- 0.0285  0.7110 +- 0.0261  0.7931 +- 0.0246
# 0.5  0.5020 +- 0.0271  0.4157 +- 0.0202  0.7630 +- 0.0208  0.8195 +- 0.0138
# 1.0  0.3840 +- 0.0201  0.3281 +- 0.0795  0.8370 +- 0.0203  0.8590 +- 0.0387
# 1.5  0.2808 +- 0.0276  0.2739 +- 0.0634  0.8815 +- 0.0136  0.8810 +- 0.0286
# 2.0  0.1911 +- 0.0311  0.2327 +- 0.0861  0.9295 +- 0.0165  0.9107 +- 0.0259
# 3.0  0.0837 +- 0.0333  0.1070 +- 0.0245  0.9695 +- 0.0156  0.9597 +- 0.0085
# 4.0  0.0252 +- 0.0146  0.0648 +- 0.0160  0.9905 +- 0.0061  0.9785 +- 0.0049
# 5.0  0.0031 +- 0.0047  0.0290 +- 0.0468  0.9985 +- 0.0023  0.9975 +- 0.0027
#
#      hidden_channels  dropout    lr  weight_decay    id
# 0.1               64      0.3  0.10         0.001   101
# 0.5               64      0.3  0.10         0.001   911
# 1.0               64      0.3  0.01         0.001  1751
# 1.5               64      0.3  0.01         0.001  2561
# ...

# %% [markdown]
# # LP

# %%
start_id = 1
end_id = 630
n_seeds = 30
K_l = [0.1]
hyperparams = ["lp_alpha"]
collection="trn_csbm_lp"
utils.get_best_hyperparams(start_id, end_id, n_seeds, hyperparams, K_l, collection)
# Out:
#               ValLoss           TrnLoss            ValAcc            TrnAcc  \
# 0.1  0.6027 +- 0.0050  0.4617 +- 0.0043  0.8775 +- 0.0213  0.9993 +- 0.0006
#
#      lp_alpha   id
# 0.1       0.7  421

# %% [markdown]
# ## LinearGCN

# %%
start_id = 1
end_id = 2880
n_seeds = 10
K_l = [0.1, 0.5, 1, 1.5, 2, 3, 4, 5]
hyperparams = ["dropout", "lr", "weight_decay"]
collection="trn_csbm_lineargcn"
utils.get_best_hyperparams(start_id, end_id, n_seeds, hyperparams, K_l, collection)
# Out:
#               ValLoss           TrnLoss            ValAcc            TrnAcc  \
# 0.1  0.6522 +- 0.0221  0.6808 +- 0.0110  0.6280 +- 0.0234  0.5927 +- 0.0258
# 0.5  0.5542 +- 0.0368  0.6225 +- 0.0220  0.7155 +- 0.0358  0.6725 +- 0.0293
# 1.0  0.3852 +- 0.0397  0.4707 +- 0.0397  0.8310 +- 0.0271  0.7904 +- 0.0173
# 1.5  0.2643 +- 0.0355  0.3405 +- 0.0335  0.8955 +- 0.0221  0.8655 +- 0.0135
# 2.0  0.1936 +- 0.0347  0.2448 +- 0.0297  0.9260 +- 0.0197  0.9044 +- 0.0152
# 3.0  0.1291 +- 0.0416  0.1669 +- 0.0324  0.9495 +- 0.0177  0.9357 +- 0.0124
# 4.0  0.1057 +- 0.0362  0.1310 +- 0.0185  0.9600 +- 0.0166  0.9490 +- 0.0083
# 5.0  0.0944 +- 0.0354  0.1247 +- 0.0296  0.9640 +- 0.0169  0.9522 +- 0.0085
#
#      dropout   lr  weight_decay    id
# 0.1      0.5  0.1        0.0001   261
# 0.5      0.5  0.1        0.0001   621
# 1.0      0.5  0.1        0.0001   981
# 1.5      0.5  0.1        0.0001  1341
# 2.0      0.5  0.1        0.0001  1701
# 3.0      0.5  0.1        0.0010  2051
# ...

# %% [markdown]
# # SGC (PyTorch Geometric Implementation with Dropout)

# %%
start_id = 1
end_id = 18000
n_seeds = 10
K_l = [0.1, 0.5, 1, 1.5, 2, 3, 4, 5]
hyperparams = ["K", "dropout", "lr", "weight_decay"]
collection="trn_csbm_sgc"
utils.get_best_hyperparams(start_id, end_id, n_seeds, hyperparams, K_l, collection)
# Out:
#               ValLoss           TrnLoss            ValAcc            TrnAcc  \
# 0.1  0.6442 +- 0.0207  0.6662 +- 0.0114  0.6560 +- 0.0492  0.6191 +- 0.0292
# 0.5  0.5365 +- 0.0479  0.5786 +- 0.0282  0.7620 +- 0.0420  0.7280 +- 0.0225
# 1.0  0.3741 +- 0.0479  0.4486 +- 0.0313  0.8540 +- 0.0259  0.8105 +- 0.0205
# 1.5  0.2701 +- 0.0388  0.3292 +- 0.0280  0.8960 +- 0.0241  0.8700 +- 0.0149
# 2.0  0.1949 +- 0.0335  0.3226 +- 0.0387  0.9265 +- 0.0163  0.8786 +- 0.0109
# 3.0  0.1289 +- 0.0391  0.2045 +- 0.0330  0.9475 +- 0.0165  0.9234 +- 0.0117
# 4.0  0.1022 +- 0.0248  0.2156 +- 0.0247  0.9590 +- 0.0092  0.9205 +- 0.0115
# 5.0  0.0852 +- 0.0225  0.1671 +- 0.0238  0.9650 +- 0.0107  0.9394 +- 0.0095
#
#      K  dropout   lr  weight_decay     id
# 0.1  5      0.3  0.2        0.0001   1371
# 0.5  5      0.0  0.2        0.0001   2871
# 1.0  4      0.0  0.2        0.0001   4971
# 1.5  2      0.0  0.2        0.0010   6911
# 2.0  2      0.3  0.2        0.0001   9921
# ...
